# %% [markdown]
# # Welcome To The Pluto Realty Database!
#
#     * User Guide Written by:
#         Anthony Sesay
#         5/12/16
#
# ## Description:
#
# This is a database application for Pluto Realty, Inc. (Pluto) to help it in managing the rental of real estate properties across the country.
#
# The intended users of the application are the employees of Pluto. It is assumed that for this guide this notebook will be ran in VS code or in browser vis JupyterLab and access to MySQL server.
#
# Now let's get started

# %% [markdown]
# ## Step 1: Setup
#
# First This code segemnt will conect your client to your MySQL server to get started.
#
# All you need to do is to run this code block and enter your user and password for your mysql server.

# %%
# %pip install jupysql sqlalchemy pymysql mysql-connector-python

# %load_ext sql
import getpass

db_user = getpass.getpass('Enter username: ')
db_password = getpass.getpass('Enter password: ')
db_host = 'localhost'

# Create DB using a temporary connector (fine to keep this part)
import mysql.connector

con = mysql.connector.connect(
    host=db_host,
    user=db_user,
    password=db_password
)

cursor = con.cursor()
cursor.execute("CREATE DATABASE IF NOT EXISTS PlutoRealty")
cursor.close()
con.close()

# Connect SQL magic (IMPORTANT CHANGE: pymysql, not mysqlconnector)
import os
os.environ["DATABASE_URL"] = f"mysql+pymysql://{db_user}:{db_password}@{db_host}/PlutoRealty"
# %sql
# Out:
# Requirement already satisfied: jupysql in c:\users\antsh\anaconda3\lib\site-packages (0.11.1)
# Requirement already satisfied: sqlalchemy in c:\users\antsh\anaconda3\lib\site-packages (2.0.43)
# Requirement already satisfied: pymysql in c:\users\antsh\anaconda3\lib\site-packages (1.1.3)
# Requirement already satisfied: mysql-connector-python in c:\users\antsh\anaconda3\lib\site-packages (9.7.0)
# Requirement already satisfied: prettytable>=3.12.0 in c:\users\antsh\anaconda3\lib\site-packages (from jupysql) (3.17.0)
# Requirement already satisfied: sqlparse in c:\users\antsh\anaconda3\lib\site-packages (from jupysql) (0.5.5)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\antsh\anaconda3\lib\site-packages (from jupysql) (0.2.0)
# Requirement already satisfied: jinja2 in c:\users\antsh\anaconda3\lib\site-packages (from jupysql) (3.1.6)
# Requirement already satisfied: sqlglot>=11.3.7 in c:\users\antsh\anaconda3\lib\site-packages (from jupysql) (30.8.0)
# Requirement already satisfied: jupysql-plugin>=0.4.2 in c:\users\antsh\anaconda3\lib\site-packages (from jupysql) (0.4.5)
# Requirement already satisfied: ploomber-core>=0.2.7 in c:\users\antsh\anaconda3\lib\site-packages (from jupysql) (0.2.27)
# Requirement already satisfied: greenlet>=1 in c:\users\antsh\anaconda3\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\antsh\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: pyyaml in c:\users\antsh\anaconda3\lib\site-packages (from ploomber-core>=0.2.7->jupysql) (6.0.3)
# Requirement already satisfied: posthog>=3.0 in c:\users\antsh\anaconda3\lib\site-packages (from ploomber-core>=0.2.7->jupysql) (7.14.2)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\antsh\anaconda3\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.32.5)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\antsh\anaconda3\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\antsh\anaconda3\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\antsh\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\antsh\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\antsh\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\antsh\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2026.1.4)
# Requirement already satisfied: wcwidth in c:\users\antsh\anaconda3\lib\site-packages (from prettytable>=3.12.0->jupysql) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\antsh\anaconda3\lib\site-packages (from jinja2->jupysql) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Enter username:  ········
# Enter password:  ········

# %% [markdown]
# ## Step 2: Creating and Loading The Database
#
# Now that you are able to connect this notebook to a database, run the three SQL scripts in MySQL Workbench or anything that can interact with databases
#
# - **`1. createAll.sql`** — Creates all tables, constraints, and triggers
# - **`2. loadAll.sql`** — Inserts all sample data into the tables
#
# The dropALL file isn't needed to create the database, but it is useful for deleting tables and reseting
#
# - **`dropAll.sql`** — Drops any existing tables so the setup starts fresh
#
# Similarly, queryAll isn't required either, but used for running specifc statements in your workbench
#
# - **'queryAll'**
# -

# %% [markdown]
# After that step, now the Database is ready to be used. Below are some example activities to show how to use it and a report for users

# %% [markdown]
# ### Activities
#
# To write a query begin the code block with %%sql and then write the statement you wish to execute. The following are example activites you can do

# %%
# %%sql
# SHOW TABLES;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# 11 rows affected.
# +-----------------------+
# | Tables_in_plutorealty |
# +-----------------------+
# |       associate       |
# |        clients        |
# |        contract       |
# |        employee       |
# |         lease         |
# |          owns         |
# |        partner        |
# |         person        |
# |     propertyowner     |
# |     rentalproperty    |
# +-----------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# 1. Edit the details/characteristics of a given property.

# %%
# %%sql
# UPDATE RentalProperty SET rent = 1500.00 WHERE property_number = 1;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# 1 rows affected.
# ++
# ||
# ++
# ++

# %% [markdown]
# 2. Create a new client.

# %%
# %%sql
# INSERT INTO Person (id, p_name, address, phone, email) VALUES
# (30, 'Fred Flintstone', '123 Main St, Anytown, USA', '123-456-7890', 'fredflintstone@email.com');
# INSERT INTO Clients (id) VALUES (30);
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# RuntimeError: (pymysql.err.IntegrityError) (1062, "Duplicate entry '30' for key 'person.PRIMARY'")
# [SQL: INSERT INTO Person (id, p_name, address, phone, email) VALUES
# (30, 'Fred Flintstone', '123 Main St, Anytown, USA', '123-456-7890', 'fredflintstone@email.com');]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %% [markdown]
# 3. Enter information for a new property viewing.

# %%
# %%sql
# INSERT INTO ViewProperty (client_id, associate_id, property_number, view_time) VALUES
# (30, 4, 10, '2026-05-15 14:00:00');
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# RuntimeError: (pymysql.err.IntegrityError) (1452, 'Cannot add or update a child row: a foreign key constraint fails (`plutorealty`.`viewproperty`, CONSTRAINT `viewproperty_ibfk_3` FOREIGN KEY (`property_number`) REFERENCES `rentalproperty` (`property_number`))')
# [SQL: INSERT INTO ViewProperty (client_id, associate_id, property_number, view_time) VALUES
# (30, 4, 10, '2026-05-15 14:00:00');]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %% [markdown]
# 4. Discard a given property (and all its associated information).
#
# - To delete a tuple, first you want to delete from the relation tables that reference it, then entities that reference it and lastly itself

# %%
# %%sql
# DELETE FROM Contract WHERE property_number = 10;
# DELETE FROM ViewProperty WHERE property_number = 10;
# DELETE FROM Owns WHERE property_number = 10;
# DELETE FROM Lease WHERE property_number = 10;
# DELETE FROM RentalProperty WHERE property_number = 10;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# ++
# ||
# ++
# ++

# %% [markdown]
# 5. Change the partner assigned to an owner and transfer all current (non-expired)
# leases of that owner to the new partner.
#     o Use a SQL transaction to ensure ACID properties (serializability) in the
#     face of other concurrent operations or failures.

# %%
# %%sql
# SELECT
#     c.partner_id,
#     c.lease_number,
#     c.client_id,
#     c.property_number,
#     o.owner_id,
#     l.finish
# FROM Contract c
# JOIN Owns o ON c.property_number = o.property_number
# JOIN Lease l ON c.lease_number = l.lease_number
#            AND c.property_number = l.property_number
# WHERE o.owner_id = 19
# ORDER BY c.lease_number;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# 3 rows affected.
# +------------+--------------+-----------+-----------------+----------+------------+
# | partner_id | lease_number | client_id | property_number | owner_id |   finish   |
# +------------+--------------+-----------+-----------------+----------+------------+
# |     1      |      1       |     7     |        1        |    19    | 2024-12-31 |
# |     1      |      2       |     8     |        2        |    19    | 2025-01-31 |
# |     2      |      7       |     13    |        3        |    19    | 2026-12-31 |
# +------------+--------------+-----------+-----------------+----------+------------+

# %%
# %%sql
# START TRANSACTION;
#
# -- Set variables
# SET @owner_id = 19;
# SET @old_partner_id = 1;
# SET @new_partner_id = 2;
#
# -- Insert new contract rows with new partner for all active leases
# INSERT INTO Contract (partner_id, lease_number, client_id, property_number)
# SELECT
#     @new_partner_id,
#     c.lease_number,
#     c.client_id,
#     c.property_number
# FROM Contract c
# JOIN Owns o ON c.property_number = o.property_number
# JOIN Lease l ON c.lease_number = l.lease_number
#            AND c.property_number = l.property_number
# WHERE o.owner_id      = @owner_id
#   AND c.partner_id    = @old_partner_id
#   AND l.finish        >= CURDATE();
#
# -- Delete old contract rows
# DELETE c FROM Contract c
# JOIN Owns o ON c.property_number = o.property_number
# JOIN Lease l ON c.lease_number = l.lease_number
#            AND c.property_number = l.property_number
# WHERE o.owner_id      = @owner_id
#   AND c.partner_id    = @old_partner_id
#   AND l.finish        >= CURDATE();
#
# COMMIT;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# ++
# ||
# ++
# ++

# %%
# %%sql
# SELECT
#     c.partner_id,
#     c.lease_number,
#     c.client_id,
#     c.property_number,
#     o.owner_id,
#     l.finish
# FROM Contract c
# JOIN Owns o ON c.property_number = o.property_number
# JOIN Lease l ON c.lease_number = l.lease_number
#            AND c.property_number = l.property_number
# WHERE o.owner_id = 19
# ORDER BY c.lease_number;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# 3 rows affected.
# +------------+--------------+-----------+-----------------+----------+------------+
# | partner_id | lease_number | client_id | property_number | owner_id |   finish   |
# +------------+--------------+-----------+-----------------+----------+------------+
# |     1      |      1       |     7     |        1        |    19    | 2024-12-31 |
# |     1      |      2       |     8     |        2        |    19    | 2025-01-31 |
# |     2      |      7       |     13    |        3        |    19    | 2026-12-31 |
# +------------+--------------+-----------+-----------------+----------+------------+

# %% [markdown]
# ### Reports
# 1. List the names of all (unique) clients.

# %%
# %%sql
#
# Select distinct p_name from Clients join Person on Clients.id = Person.id;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# 13 rows affected.
# +-----------------+
# |      p_name     |
# +-----------------+
# |  Justice Parrot |
# | Terraine Gordon |
# |   Adrian Jovel  |
# |   Victor Jovel  |
# |  Brian Ramirez  |
# |    Gabe Lopez   |
# | Abdoulaye Drame |
# |   Shean Garcia  |
# |   Yuji Itadori  |
# |   Satoru Gojo   |
# +-----------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# 2. Find the unique names of owners and total square footage of all the properties
# they own.

# %%
# %%sql
# select distinct p_name, sum(area)
# from Owns
# 	join Person on Owns.owner_id = Person.id
# 	join RentalProperty on Owns.property_number = RentalProperty.property_number
# group by Person.p_name;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# 8 rows affected.
# +-------------------+-----------+
# |       p_name      | sum(area) |
# +-------------------+-----------+
# |  Elizabeth Moser  |    4955   |
# |   New Owner Test  |    4755   |
# |     Ryan Zheng    |    4000   |
# |    Elaine Cheng   |    9000   |
# |   Johnny Joestar  |    8500   |
# | Gumball Watterson |   37000   |
# |   Tokio Kurohara  |   41000   |
# |      Pat Doe      |    5000   |
# +-------------------+-----------+

# %% [markdown]
# 3. Find the properties shown by each associate in a given month.

# %%
# %%sql
# SELECT
#     MONTH(view_time) AS view_month,
#     property_number,
#     COUNT(*) AS num_viewings
# FROM ViewProperty
# WHERE view_time >= '2026-05-01'
#   AND view_time < '2026-06-02'
# GROUP BY MONTH(view_time), property_number
# ORDER BY num_viewings DESC;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# 13 rows affected.
# +------------+-----------------+--------------+
# | view_month | property_number | num_viewings |
# +------------+-----------------+--------------+
# |     5      |        1        |      1       |
# |     5      |        2        |      1       |
# |     5      |        3        |      1       |
# |     5      |        4        |      1       |
# |     5      |        8        |      1       |
# |     5      |        5        |      1       |
# |     5      |        6        |      1       |
# |     5      |        9        |      1       |
# |     5      |        11       |      1       |
# |     5      |        12       |      1       |
# +------------+-----------------+--------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# 4. Find the most popular properties (in terms of number of viewings) in a given
# period (range of dates).

# %%
# %%sql
# SELECT
#     ViewProperty.property_number,
#     address,
#     type,
#     COUNT(*) AS viewings
# FROM ViewProperty
# JOIN RentalProperty ON ViewProperty.property_number = RentalProperty.property_number
# WHERE view_time >= '2026-01-01'
#   AND view_time <  '2026-07-02'
# GROUP BY property_number, address, type
# ORDER BY viewings DESC;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# 13 rows affected.
# +-----------------+---------------------+-------------+----------+
# | property_number |       address       |     type    | viewings |
# +-----------------+---------------------+-------------+----------+
# |        1        |    10 Sunset Blvd   | Residential |    1     |
# |        2        |    20 Sunrise Ave   | Residential |    1     |
# |        3        |   30 Moonlight Dr   | Residential |    1     |
# |        4        |    40 Starview Ln   | Residential |    1     |
# |        8        |   200 Commerce Rd   |  Commercial |    1     |
# |        5        |    50 Hilltop Rd    | Residential |    1     |
# |        6        |     60 Valley St    | Residential |    1     |
# |        9        |    300 Market St    |  Commercial |    1     |
# |        11       | 500 Enterprise Blvd |  Commercial |    1     |
# |        12       |   600 Corporate Dr  |  Commercial |    1     |
# +-----------------+---------------------+-------------+----------+
# Truncated to displaylimit of 10.

# %% [markdown]
# 5. Find the total rent due to each property owner in a given month and year.

# %%
# %%sql
# SELECT
#     o.owner_id,
#     p.p_name,
#     SUM(l.rent) AS total_rent
# FROM Lease l
# JOIN Owns o ON l.property_number = o.property_number
# JOIN Person p ON o.owner_id = p.id
# WHERE YEAR(l.start)  = 2024
#   AND MONTH(l.start) = 5
# GROUP BY o.owner_id, p.p_name;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# 1 rows affected.
# +----------+-------------------+------------+
# | owner_id |       p_name      | total_rent |
# +----------+-------------------+------------+
# |    23    | Gumball Watterson |  5000.00   |
# +----------+-------------------+------------+

# %% [markdown]
# 6. Find the unique names of clients that were ever shown at least three or more
# unique residential properties owned by a given owner.

# %%
# %%sql
# SELECT
#     vp.client_id,
#     p.p_name
# FROM ViewProperty vp
# JOIN Owns o  ON vp.property_number = o.property_number
# JOIN RentalProperty rp ON vp.property_number = rp.property_number
# JOIN Person p ON vp.client_id = p.id
# WHERE o.owner_id = 19
#   AND rp.type = 'Residential'
# GROUP BY vp.client_id, p.p_name
# HAVING COUNT(DISTINCT vp.property_number) >= 3;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# 1 rows affected.
# +-----------+----------------+
# | client_id |     p_name     |
# +-----------+----------------+
# |     7     | Justice Parrot |
# +-----------+----------------+

# %% [markdown]
# 7. Find the unique names of owners that have a residential property in every city
# where Pat Doe owns a commercial property.

# %%
# %%sql
# SELECT
#     o.owner_id,
#     pe.p_name
# FROM Owns o
# JOIN RentalProperty rp ON o.property_number = rp.property_number
# JOIN Person pe ON o.owner_id = pe.id
# WHERE rp.type = 'residential'
#   AND SUBSTRING_INDEX(rp.address, ',', -1) IN (
#     SELECT DISTINCT SUBSTRING_INDEX(rp2.address, ',', -1)
#     FROM RentalProperty rp2
#     JOIN Owns o2 ON rp2.property_number = o2.property_number
#     JOIN Person pe2 ON o2.owner_id = pe2.id
#     WHERE pe2.p_name = 'Pat Doe'
#       AND rp2.type = 'commercial'
# )
# GROUP BY o.owner_id, pe.p_name
# HAVING COUNT(DISTINCT SUBSTRING_INDEX(rp.address, ',', -1)) = (
#     SELECT COUNT(DISTINCT SUBSTRING_INDEX(rp2.address, ',', -1))
#     FROM RentalProperty rp2
#     JOIN Owns o2 ON rp2.property_number = o2.property_number
#     JOIN Person pe2 ON o2.owner_id = pe2.id
#     WHERE pe2.p_name = 'Pat Doe'
#       AND rp2.type = 'commercial'
# );
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# 1 rows affected.
# +----------+-----------------+
# | owner_id |      p_name     |
# +----------+-----------------+
# |    19    | Elizabeth Moser |
# +----------+-----------------+

# %% [markdown]
# 8. Find the top-3 partners with respect to number of properties leased in the current
# year.

# %%
# %%sql
# SELECT
#     partner_id,
#     p_name,
#     COUNT(DISTINCT Lease.property_number) AS properties_leased
# FROM Contract
# JOIN Lease  ON Contract.lease_number = Lease.lease_number
#              AND Contract.property_number = Lease.property_number
# JOIN Person ON Contract.partner_id = Person.id
# WHERE YEAR(Lease.start) = 2026
# GROUP BY Contract.partner_id, Person.p_name
# ORDER BY num_properties_leased DESC
# LIMIT 3;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# RuntimeError: (pymysql.err.OperationalError) (1054, "Unknown column 'num_properties_leased' in 'order clause'")
# [SQL: SELECT
#     partner_id,
#     p_name,
#     COUNT(DISTINCT Lease.property_number) AS properties_leased
# FROM Contract
# JOIN Lease  ON Contract.lease_number = Lease.lease_number
#              AND Contract.property_number = Lease.property_number
# JOIN Person ON Contract.partner_id = Person.id
# WHERE YEAR(Lease.start) = 2026
# GROUP BY Contract.partner_id, Person.p_name
# ORDER BY num_properties_leased DESC
# LIMIT 3;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# 9. total management fees due to Pluto in the last 3 months.

# %%
# %%sql
# SELECT
#     SUM(management_fee) AS total_management_fees
# FROM RentalProperty
# JOIN Lease ON RentalProperty.property_number = Lease.property_number
# WHERE start >= DATE_SUB(CURDATE(), INTERVAL 3 MONTH)
#   AND start <  CURDATE();
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/PlutoRealty'
# 1 rows affected.
# +-----------------------+
# | total_management_fees |
# +-----------------------+
# |        1450.00        |
# +-----------------------+

# %% [markdown]
# ### Congrats!! You've reached the end
#
# Now that you've completed the tutorial, you're free to start quering to your heart's content. Stay tuned for the SQL

# %%
#statements go here
# %%sql
# Out:
# UsageError: Line magic function `%%sql` not found.
